# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split as tts
import sagemaker
import boto3
from sagemaker import Session
import io
import sagemaker.amazon.common as smac
import os
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

# %%
'''Again, since we're working with the same dataset, let's create the same coding we did earlier, but this time with some modifications'''

# %%
df = pd.read_csv('house_prices.csv')

# %%
# todo CLEAN UP DATA --------------------

# %%
df.drop(columns=['id', 'date', 'sqft_living15', 'sqft_lot15'], inplace=True)

# %%
# todo ATTRIBUTES SELECTION --------------------

# %%
training = df.iloc[0:15129, :]
test = df.iloc[15129:, :]
X_test = test.iloc[:, 1:17].values
y_test = test.iloc[:, 0].values

training.to_csv('house_prices_train_xgboost.csv', header=False, index=False)
test.to_csv('house_prices_test_xgboost.csv', header=False, index=False)

# %%
session = sagemaker.Session()
bucket = 'tests-aws-sagemaker'
model = 'house_prices_xgboost'
dataset = 'house_prices'
key_train = 'houses-train-data-xgboost'
key_test = 'houses-test-data-xgboost'
role = sagemaker.get_execution_role()

s3_train_data = 's3://{}/{}/train/{}'.format(bucket, dataset, key_train) # 's3://tests-aws-sagemaker/house_prices/train/houses-train-data-xgboost'
s3_test_data = 's3://{}/{}/test/{}'.format(bucket, dataset, key_test) # 's3://tests-aws-sagemaker/house_prices_xgboost/test/houses-test-data-xgboost'
output_location = 's3://{}/{}/output'.format(bucket, model) # 's3://tests-aws-sagemaker/house_prices_xgboost/output'

container = sagemaker.image_uris.retrieve(framework='xgboost', region=boto3.Session().region_name, version='latest')

# %%
with open('house_prices_train_xgboost.csv', 'rb') as f:
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(dataset, 'train', key_train)).upload_fileobj(f)
          
with open('house_prices_test_xgboost.csv', 'rb') as f:
    boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(dataset, 'test', key_test)).upload_fileobj(f)

# %%
# todo TUNING --------------------

# %%
'''At this part we can start to set some parameters for the tuning, rounds, etc. I made a list for quick comprehension'''

# %%
# ETA = PREVENT OVERFITTING
# ALPHA = ADD EXTRA WEIGHTS TO HELP KEEP THE MODEL MORE CONSERVATIVE
# MIN CHILD WEIGHT = MINIMAL NUMBER OF INSTANCES REQUIRED TO BE CONTRUCTED IN THE DECISION TREE
# MAX_DEPTH = MAX DEPTH OF THE TREE, WHICH MAKES THE MODEL MORE COMPLEX, AND MORE LIKELY TO OVERFIT
# NUM_ROUND = NUMBER OF ROUNDS TO RUN THE TRAINING
# RESOURCELIMITS = MAXIMUM OF TRAINING JOBS AND HOW MANY PARALEL ALGORITHM TRANINGS IT SHOULD RUN AT THE SAME TIME
# STRATEGY = BAYESIAN FOR PARAMETERS DEFINITION
# HYPERPARAMETERTUNINJOBOBJECTIVE = WHAT KIND OF METRIC WE WANT TO CHECK AND WHAT WOULD BE THE GOAL

# %%
tuning_job_config = {
    "ParameterRanges": {
      "CategoricalParameterRanges": [],
      "ContinuousParameterRanges": [
        {
          "MaxValue": "1",
          "MinValue": "0",
          "Name": "eta"
        },
        {
          "MaxValue": "2",
          "MinValue": "0",
          "Name": "alpha"
        },
        {
          "MaxValue": "10",
          "MinValue": "1",
          "Name": "min_child_weight"
        }
      ],
      "IntegerParameterRanges": [
        {
          "MaxValue": "10",
          "MinValue": "1",
          "Name": "max_depth"
        }
      ],
      "IntegerParameterRanges": [
        {
          "MaxValue": "300",
          "MinValue": "50",
          "Name": "num_round"
        }
      ]
    },
    "ResourceLimits": {
      "MaxNumberOfTrainingJobs": 9,
      "MaxParallelTrainingJobs": 3
    },
    "Strategy": "Bayesian",
    "HyperParameterTuningJobObjective": {
      "MetricName": "validation:rmse",
      "Type": "Minimize"
    }
  }

# %%
'''And now we cset some parameters for the training, paths, metrics,etc. Here's another list of parameters for quick compreension'''

# %%
# ALGORITHMSPECIFICATION = THE IMAGE WE WANT TO USE, AND THE METHOD
# INPUTDATACONFIG = THE PATH, NAME AND SOURCE OF THE DATA WE WILL BE USING
# OUTPUTDATACONFIG = THE PATH WE WANT TO SAVE THE TRAINING
# RESOURCECONFIG = NUMBER OF INSTANCES, TYPE OF INSTANCE AND VOLUME SIZE
# ROLEARN = ROLE ACCESS
# STATICHYPERPARAMETERS = KIND OF METRICS, REG:LINEAR FOR LINEAR REGRESSION, DROPOUT TO AVOID OVERFITTING AND TWEEDIE TO CONTROL THE VARIANCE
# STOPPINGCONDITION = MAX TIME WE WANT THE ALGORITHM TO BE FULLY EXECUTED

# %%
training_job_definition = {
    "AlgorithmSpecification": {
      "TrainingImage": container,
      "TrainingInputMode": "File"
    },
    "InputDataConfig": [
      {
        "ChannelName": "train",
        "CompressionType": "None",
        "ContentType": "csv",
        "DataSource": {
          "S3DataSource": {
            "S3DataDistributionType": "FullyReplicated",
            "S3DataType": "S3Prefix",
            "S3Uri": s3_train_data
          }
        }
      },
      {
        "ChannelName": "validation",
        "CompressionType": "None",
        "ContentType": "csv",
        "DataSource": {
          "S3DataSource": {
            "S3DataDistributionType": "FullyReplicated",
            "S3DataType": "S3Prefix",
            "S3Uri": s3_test_data
          }
        }
      }
    ],
    "OutputDataConfig": {
      "S3OutputPath": "s3://{}/{}/output".format(bucket, model)
    },
    "ResourceConfig": {
      "InstanceCount": 2,
      "InstanceType": "ml.c4.2xlarge",
      "VolumeSizeInGB": 10
    },
    "RoleArn": role,
    "StaticHyperParameters": {
      "eval_metric": "rmse",
      "objective": "reg:linear",
      "rate_drop": "0.3",
      "tweedie_variance_power": "1.4"
    },
    "StoppingCondition": {
      "MaxRuntimeInSeconds": 43200
    }
}

# %%
'''Now we can start the tuning tests and check which one of the rounds had the better result, we're taking a look at that at Amazon

# %%
smclient = boto3.client('sagemaker')
smclient.create_hyper_parameter_tuning_job(HyperParameterTuningJobName="xgboosttuninghouses2", HyperParameterTuningJobConfig=tuning_job_config,
                                          TrainingJobDefinition=training_job_definition)
# Out:
# {'HyperParameterTuningJobArn': 'arn:aws:sagemaker:us-west-2:217214575618:hyper-parameter-tuning-job/xgboosttuninghouses2',
#  'ResponseMetadata': {'RequestId': '91c6d208-3e59-4066-b61c-712184e08894',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '91c6d208-3e59-4066-b61c-712184e08894',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '121',
#    'date': 'Sat, 10 Sep 2022 21:49:53 GMT'},
#   'RetryAttempts': 0}}

# %%
# PRINT 13

# %%
'''Now that we have the best parameters set up we can create the best model with the parameters that were chosen'''

# %%
# CREATION WITH BEST PARAMETERS

# %%
container = sagemaker.image_uris.retrieve(framework='xgboost', region=boto3.Session().region_name, version='latest')
xgboost_tuning = sagemaker.estimator.Estimator(image_uri=container, role=role, instance_count=1, instance_type='ml.m5.2xlarge',
                                               output_path=output_location, sagemaker_session=session)

xgboost_tuning.set_hyperparameters(num_round = 215, eta = 0.07545286994225804, min_child_weight = 2.4061755279241996,
                                   alpha = 1.5934054040797325, tweedie_variance_power = 1.4, rate_drop = 0.3)

# %%
'''With everything ready, let's train the best parameter model'''

# %%
train_input = sagemaker.inputs.TrainingInput(s3_data=s3_train_data, content_type='csv', s3_data_type='S3Prefix')
test_input = sagemaker.inputs.TrainingInput(s3_data=s3_test_data, content_type='csv', s3_data_type='S3Prefix')
data_channels = {'train': train_input, 'validation': test_input}
xgboost_tuning.fit(data_channels)
# Out:
# 2022-09-10 22:22:33 Starting - Starting the training job...
# 2022-09-10 22:22:57 Starting - Preparing the instances for trainingProfilerReport-1662848553: InProgress
# ......
# 2022-09-10 22:23:57 Downloading - Downloading input data...
# 2022-09-10 22:24:27 Training - Downloading the training image.....Arguments: train
# [2022-09-10:22:25:10:INFO] Running standalone xgboost training.
# [2022-09-10:22:25:10:INFO] File size need to be processed in the node: 1.55mb. Available memory size in the node: 23858.36mb
# [2022-09-10:22:25:10:INFO] Determined delimiter of CSV input is ','
# [22:25:10] S3DistributionType set as FullyReplicated
# [22:25:11] 15129x16 matrix with 242064 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2022-09-10:22:25:11:INFO] Determined delimiter of CSV input is ','
# [22:25:11] S3DistributionType set as FullyReplicated
# [22:25:11] 6484x16 matrix with 103744 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-rmse:601767#011validation-rmse:622558
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-rmse:560583#011validation-rmse:580436
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-rmse:522658#011validation-rmse:541250
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-rmse:487621#011validation-rmse:504756
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-rmse:455303#011validation-rmse:471848
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-rmse:425577#011validation-rmse:441157
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-rmse:398307#011validation-rmse:413538
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-rmse:372955#011validation-rmse:387886
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-rmse:349455#011validation-rmse:364092
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-rmse:328053#011validation-rmse:343083
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-rmse:308281#011validation-rmse:323640
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-rmse:290134#011validation-rmse:305633
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-rmse:273443#011validation-rmse:289323
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-rmse:258233#011validation-rmse:274819
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-rmse:244010#011validation-rmse:261068
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-rmse:230965#011validation-rmse:248439
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-rmse:219233#011validation-rmse:237046
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-rmse:208250#011validation-rmse:227037
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-rmse:198296#011validation-rmse:217508
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-rmse:189080#011validation-rmse:208389
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-rmse:180761#011validation-rmse:200796
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-rmse:173064#011validation-rmse:193859
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-rmse:166041#011validation-rmse:186955
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
#
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [131]#011train-rmse:77968.3#011validation-rmse:122671
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [132]#011train-rmse:77758#011validation-rmse:122669
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 0 pruned nodes, max_depth=6
# [133]#011train-rmse:77418.1#011validation-rmse:122477
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [134]#011train-rmse:77308.2#011validation-rmse:122481
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [135]#011train-rmse:77072.2#011validation-rmse:122284
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [136]#011train-rmse:76981.5#011validation-rmse:122269
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [137]#011train-rmse:76809.6#011validation-rmse:122183
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [138]#011train-rmse:76653.9#011validation-rmse:122160
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [139]#011train-rmse:76520.1#011validation-rmse:122148
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [140]#011train-rmse:76391.8#011validation-rmse:122072
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [141]#011train-rmse:76211#011validation-rmse:122022
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [142]#011train-rmse:76063#011validation-rmse:121997
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [143]#011train-rmse:75978#011validation-rmse:122052
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [144]#011train-rmse:75836.5#011validation-rmse:122044
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [145]#011train-rmse:75773.4#011validation-rmse:122053
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [146]#011train-rmse:75591.3#011validation-rmse:122002
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [147]#011train-rmse:75498.5#011validation-rmse:121974
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [148]#011train-rmse:75371#011validation-rmse:121933
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [149]#011train-rmse:75287.2#011validation-rmse:121934
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [150]#011train-rmse:75122.2#011validation-rmse:121841
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [151]#011train-rmse:75022.8#011validation-rmse:121821
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [152]#011train-rmse:74980.4#011validation-rmse:121812
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [153]#011train-rmse:74875.4#011validation-rmse:121816
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [154]#011train-rmse:74827.3#011validation-rmse:121809
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [155]#011train-rmse:74686.4#011validation-rmse:121769
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [156]#011train-rmse:74616.9#011validation-rmse:121773
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [157]#011train-rmse:74476.4#011validation-rmse:121729
# [22:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [158]#011train-rmse:74327.1#011validation-rmse:121653
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [159]#011train-rmse:74229.8#011validation-rmse:121676
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [160]#011train-rmse:74156.5#011validation-rmse:121649
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [161]#011train-rmse:74121.8#011validation-rmse:121650
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [162]#011train-rmse:73994.7#011validation-rmse:121630
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [163]#011train-rmse:73896.1#011validation-rmse:121617
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [164]#011train-rmse:73842.9#011validation-rmse:121575
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [165]#011train-rmse:73800.9#011validation-rmse:121573
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [166]#011train-rmse:73714.2#011validation-rmse:121519
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [167]#011train-rmse:73586.9#011validation-rmse:121483
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [168]#011train-rmse:73503.5#011validation-rmse:121456
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [169]#011train-rmse:73417.9#011validation-rmse:121438
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [170]#011train-rmse:73309.2#011validation-rmse:121424
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [171]#011train-rmse:73172.1#011validation-rmse:121382
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [172]#011train-rmse:73107#011validation-rmse:121367
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [173]#011train-rmse:72992.7#011validation-rmse:121356
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [174]#011train-rmse:72895.8#011validation-rmse:121312
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [175]#011train-rmse:72822.9#011validation-rmse:121285
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [176]#011train-rmse:72685.7#011validation-rmse:121276
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [177]#011train-rmse:72605.4#011validation-rmse:121262
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [178]#011train-rmse:72451#011validation-rmse:121254
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [179]#011train-rmse:72323.8#011validation-rmse:121211
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [180]#011train-rmse:72248.9#011validation-rmse:121186
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [181]#011train-rmse:72169.3#011validation-rmse:121196
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [182]#011train-rmse:72085.7#011validation-rmse:121188
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [183]#011train-rmse:71816.8#011validation-rmse:121114
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [184]#011train-rmse:71710.9#011validation-rmse:121087
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [185]#011train-rmse:71552.9#011validation-rmse:121046
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [186]#011train-rmse:71374#011validation-rmse:120942
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [187]#011train-rmse:71244.9#011validation-rmse:120949
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [188]#011train-rmse:71197.9#011validation-rmse:120947
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [189]#011train-rmse:71047#011validation-rmse:120896
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [190]#011train-rmse:70939.3#011validation-rmse:120867
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [191]#011train-rmse:70805.4#011validation-rmse:120812
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [192]#011train-rmse:70733.8#011validation-rmse:120829
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [193]#011train-rmse:70647.4#011validation-rmse:120820
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [194]#011train-rmse:70597.4#011validation-rmse:120803
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [195]#011train-rmse:70423.3#011validation-rmse:120735
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [196]#011train-rmse:70359#011validation-rmse:120726
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [197]#011train-rmse:70188.8#011validation-rmse:120678
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [198]#011train-rmse:70036#011validation-rmse:120627
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [199]#011train-rmse:69920.5#011validation-rmse:120639
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [200]#011train-rmse:69817#011validation-rmse:120595
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [201]#011train-rmse:69691.8#011validation-rmse:120594
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [202]#011train-rmse:69555.6#011validation-rmse:120565
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [203]#011train-rmse:69499.3#011validation-rmse:120581
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [204]#011train-rmse:69423#011validation-rmse:120582
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [205]#011train-rmse:69337.2#011validation-rmse:120562
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [206]#011train-rmse:69192.9#011validation-rmse:120477
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [207]#011train-rmse:69115#011validation-rmse:120457
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [208]#011train-rmse:69079.5#011validation-rmse:120475
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [209]#011train-rmse:68957#011validation-rmse:120457
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [210]#011train-rmse:68846.5#011validation-rmse:120482
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [211]#011train-rmse:68670.4#011validation-rmse:120479
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [212]#011train-rmse:68603.5#011validation-rmse:120467
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [213]#011train-rmse:68554.9#011validation-rmse:120480
# [22:25:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [214]#011train-rmse:68528.3#011validation-rmse:120469
#
# 2022-09-10 22:25:29 Uploading - Uploading generated training model
# 2022-09-10 22:25:29 Completed - Training job completed
# Training seconds: 93
# Billable seconds: 93

# %%
# PRINT 14

# %%
'''Let's deploy the model and convert from binary to numpy array, and check the results'''

# %%
xgboost_regressor_tuning = xgboost_tuning.deploy(initial_instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# -------!

# %%
xgboost_regressor_tuning.serializer = CSVSerializer()
predictions = np.array(xgboost_regressor_tuning.predict(X_test).decode('utf-8').split(',')).astype(np.float32)

# %%
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = math.sqrt(mean_squared_error(y_test, predictions))
print(f'MAE: {mae} | MSE:{mse} | RMSE{rmse}')
# Out:
# MAE: 67139.43489623496 | MSE:14512797938.180792 | RMSE120469.07461328318

# %%
'''We can compare the results and we'll find that the tuning helped a litle our model. For better results we can try more rounds and test more of those parameters, so we can obtain
better results, keep in mind that the no tuning had 100 rounds for test, and the tuning had only 9. With this info we can crank up the number of tries on the tuning so we can reach
even better results.

# %%
'''Don't forget to delete your endpoints, s3 buckets and '''

# %%
# xgboost_regressor_tuning.delete_endpoint()
